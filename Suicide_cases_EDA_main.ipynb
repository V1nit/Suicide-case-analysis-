# %%
#libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#data sets
df = pd.read_excel('C:/Users/DELL/Desktop/SUCIDE DATA FOR INDIA/1_Bankruptcy_Total.xlsx')
FamilyProblem = pd.read_excel('C:/Users/DELL/Desktop/SUCIDE DATA FOR INDIA/5_Family_Problems.xlsx')
FamilyPivot =  pd.read_excel('C:/Users/DELL/Desktop/SUCIDE DATA FOR INDIA/5_Family_Problems_pivot.xlsx')
Illness =  pd.read_excel('C:/Users/DELL/Desktop/SUCIDE DATA FOR INDIA/6_illness.xlsx')
IllnessPivot =  pd.read_excel('C:/Users/DELL/Desktop/SUCIDE DATA FOR INDIA/illnessPivot.xlsx')
Marriage = pd.read_excel('C:/Users/DELL/Desktop/SUCIDE DATA FOR INDIA/2_Marriage_Related.xlsx')
MarriagePivot = pd.read_excel('C:/Users/DELL/Desktop/SUCIDE DATA FOR INDIA/Marriage_problemsPivot.xlsx')

# %%
FamilyProblem.describe().T.style.background_gradient(cmap='Blues', low =0.5, high= 1.0)
# Out:
# <style type="text/css">
# #T_0d3e8_row0_col0, #T_0d3e8_row0_col3, #T_0d3e8_row1_col0, #T_0d3e8_row1_col3, #T_0d3e8_row2_col0, #T_0d3e8_row2_col3, #T_0d3e8_row3_col0, #T_0d3e8_row3_col3, #T_0d3e8_row4_col0, #T_0d3e8_row4_col3, #T_0d3e8_row5_col0, #T_0d3e8_row5_col3, #T_0d3e8_row6_col0, #T_0d3e8_row6_col3, #T_0d3e8_row7_col0, #T_0d3e8_row7_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_0d3e8_row0_col1, #T_0d3e8_row0_col2, #T_0d3e8_row0_col6, #T_0d3e8_row1_col1, #T_0d3e8_row1_col2, #T_0d3e8_row1_col7, #T_0d3e8_row2_col2, #T_0d3e8_row2_col4, #T_0d3e8_row2_col5, #T_0d3e8_row2_col7, #T_0d3e8_row3_col2, #T_0d3e8_row3_col5 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_0d3e8_row0_col4, #T_0d3e8_row5_col6 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_0d3e8_row0_col5, #T_0d3e8_row1_col5, #T_0d3e8_row1_col6, #T_0d3e8_row2_col1, #T_0d3e8_row2_col6, #T_0d3e8_row3_col1, #T_0d3e8_row3_col6, #T_0d3e8_row3_col7 {
#   background-color: #cfe1f2;
# ...

# %%
df.columns
# Out:
# Index(['States', 'Deaths', 'Year'], dtype='object')

# %%
top5_data = df[(df.States == 'MAHARASHTRA') | (df.States == 'KARNATAKA') | (df.States == 'TELANGANA') | (df.States == 'ANDHRA PRADESH')| (df.States == 'TAMIL NADU')]

# %%
top5_data.head()
# Out:
#             States  Deaths  Year
# 0   ANDHRA PRADESH     312  2015
# 11       KARNATAKA    1086  2015
# 14     MAHARASHTRA    1699  2015
# 23      TAMIL NADU     229  2015
# 24       TELANGANA     649  2015

# %%
top5_data.pivot_table(index='Year',columns='States',values='Deaths').plot(kind='bar',figsize=(30,15))
plt.show()

# %% [markdown]
# ## Family problems

# %%
FamilyProblem = FamilyProblem.iloc[:-1,:]
FamilyProblem = FamilyProblem.sort_values(by = 'Total', ascending = False)
FamilyProblem = FamilyProblem.iloc[:,:]

# %%
fig = plt.figure(figsize = (8, 4))
 
# creating the bar plot

plt.xticks(rotation='vertical')
plt.bar(FamilyProblem['States'], FamilyProblem['Total'], color = (0.2, 0.4, 0.6, 0.5),width = 0.5)
plt.xlable("States")
plt.ylable("No. of suicides due to Family problems")
plt.title("2015-21 Family problem suicide cases")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24952\1363841331.py in <module>
#       5 plt.xticks(rotation='vertical')
#       6 plt.bar(FamilyProblem['States'], FamilyProblem['Total'], color = (0.2, 0.4, 0.6, 0.5),width = 0.5)
# ----> 7 plt.xlable("States")
#       8 plt.ylable("No. of suicides due to Family problems")
#       9 plt.title("2015-21 Family problem suicide cases")
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlable'

# %%
top5_data_familyp = FamilyPivot[(FamilyPivot.States == 'MAHARASHTRA') | (FamilyPivot.States == 'WEST BENGAL') | (FamilyPivot.States == 'KERALA') | (FamilyPivot.States == 'MADHYA PRADESH')| (FamilyPivot.States == 'TAMIL NADU')]

# %%
top5_data_familyp
# Out:
#              States  Deaths  Year
# 12           KERALA    2809  2015
# 13   MADHYA PRADESH    2749  2015
# 14      MAHARASHTRA    5532  2015
# 23       TAMIL NADU    7377  2015
# 28      WEST BENGAL    3556  2015
# 48           KERALA    2852  2016
# 49   MADHYA PRADESH    2584  2016
# 50      MAHARASHTRA    5820  2016
# 59       TAMIL NADU    6092  2016
# 64      WEST BENGAL    3614  2016
# 84           KERALA    3147  2017
# 85   MADHYA PRADESH    3298  2017
# 86      MAHARASHTRA    5689  2017
# 95       TAMIL NADU    6097  2017
# 100     WEST BENGAL    3519  2017
# 120          KERALA    3213  2018
# 121  MADHYA PRADESH    3649  2018
# 122     MAHARASHTRA    6072  2018
# 131      TAMIL NADU    6433  2018
# 136     WEST BENGAL    3331  2018
# 156          KERALA    3655  2019
# 157  MADHYA PRADESH    4363  2019
# 158     MAHARASHTRA    6334  2019
# 167      TAMIL NADU    6843  2019
# 172     WEST BENGAL    2584  2019
# 192          KERALA    3575  2020
# ...

# %%
#plt.xticks(rotation='horizontal')
    top5_data_familyp.pivot_table(index='Year',columns='States',values='Deaths').plot(kind='bar',figsize=(15,8),color = plt.cm.plasma(np.linspace(0, 0.9,5)))
plt.xlabel('Years')
plt.ylabel('Deaths')
plt.xticks(rotation = 'horizontal')
plt.title( 'NO. of suicides due to Family problems')
plt.legend (loc= 'upper center')
plt.show

plt.show()
# Out:
#   File "C:\Users\DELL\AppData\Local\Temp\ipykernel_24952\1777541713.py", line 2
#     top5_data_familyp.pivot_table(index='Year',columns='States',values='Deaths').plot(kind='bar',figsize=(15,8),color = plt.cm.plasma(np.linspace(0, 0.9,5)))
#     ^
# IndentationError: unexpected indent

# %%
Illness.head()
# Out:
#               States  2015  2016  2017  2018  2019  2020  2021  Total
# 0     ANDHRA PRADESH  1916  2002  1540  1610  1845  2238  2469  13620
# 1  ARUNACHAL PRADESH    13     9     2     9     1     2     0     36
# 2              ASSAM   213   102   114   133   157   190   231   1140
# 3              BIHAR    36    36    33    27    23    43    43    241
# 4       CHHATTISGARH   896  1079  1043  1243  1143  1211  1297   7912

# %%
Illness = Illness.sort_values(by = 'Total', ascending=False)

# %%
fig = plt.figure(figsize = (8, 4))
 
# creating the bar plot

plt.xticks(rotation='vertical')
plt.bar(Illness['States'], Illness['Total'], color =(0.2, 0.4, 0.6, 0.5),width = 0.4)
plt.xlabel("States")
plt.ylabel("No. of suicides due to illness")
plt.title("2015-21 Total Illness suicide cases")
# Out:
# Text(0.5, 1.0, '2015-21 Total Illness suicide cases')

# %%
illness_top5 = IllnessPivot[(IllnessPivot.States == 'MAHARASHTRA') | (IllnessPivot.States == 'ANDHRA PRADESH') | (IllnessPivot.States == 'KERALA') | (IllnessPivot.States == 'MADHYA PRADESH')| (IllnessPivot.States == 'TAMIL NADU')]

# %%
#plt.xticks(rotation='horizontal')
illness_top5.pivot_table(index='Years',columns='States',values='Deaths').plot(kind='bar',figsize=(15,8),color =plt.cm.viridis(np.linspace(0, 1,5)) )
plt.xlabel('Years')
plt.ylabel('Deaths')
plt.xticks(rotation = 'horizontal')
plt.title( 'NO. of suicides due to illness')
plt.legend (loc= 'upper center')
plt.show

plt.show()

# %% [markdown]
# ## Marriage related issues

# %%
Marriage = Marriage.sort_values(by = 'Total' , ascending=False )

# %%
fig = plt.figure(figsize = (8, 4))
 
# creating the bar plot

plt.xticks(rotation='vertical')
plt.bar(Marriage['States'], Marriage['Total'], color =(0.2, 0.4, 0.6, 0.5),width = 0.4)
plt.xlabel("States")
plt.ylabel("No. of suicides due to Marriage Problems")
plt.title("Total Marriage related problem suicide cases from 2015-21")
# Out:
# Text(0.5, 1.0, 'Total Marriage related problem suicide cases from 2015-21')

# %%
Marriage_top5 = MarriagePivot[(MarriagePivot.States == 'MAHARASHTRA') | (MarriagePivot.States == 'UTTAR PRADESH') | (MarriagePivot.States == 'WEST BENGAL') | (MarriagePivot.States == 'MADHYA PRADESH')| (MarriagePivot.States == 'ODISHA')]

# %%
Marriage_top5.head()
# Out:
#             States  Deaths  Years
# 13  MADHYA PRADESH    1011   2015
# 14     MAHARASHTRA     706   2015
# 19          ODISHA     407   2015
# 26   UTTAR PRADESH     648   2015
# 28     WEST BENGAL     882   2015

# %%
#plt.xticks(rotation='horizontal')
Marriage_top5.pivot_table(index='Years',columns='States',values='Deaths').plot(kind='bar',figsize=(15,8),color=plt.cm.inferno(np.linspace(0, 0.8,5)))
plt.xlabel('Years')
plt.ylabel('Deaths')
plt.xticks(rotation = 'horizontal')
plt.title( 'NO. of suicides due to Marriage related problems')
plt.legend (loc= 'upper left')
plt.show

plt.show()

# %% [markdown]
# ## Total suicide cases graph

# %%
TotalYears = ['2015','2016','2017','2018','2019','2020','2021']
Totalsuicides = [133623, 131008, 129887, 130387, 141422, 153052, 165938]
plt.plot(TotalYears, Totalsuicides, color = 'orange', linewidth = 3)
plt.bar(TotalYears, Totalsuicides,color = 'royalblue')
plt.ylim(100000,170000)
plt.xlabel('Years')
plt.ylabel('Total no. of suicides')
plt.title("Total no. of suicide from 2015-21")
#plt.scatter(TotalYears, Totalsuicides)
plt.show()

# %%
TotalcasesState = pd.read_excel('C:/Users/DELL/Desktop/SUCIDE DATA FOR INDIA/Total_suicides_2015-21.xlsx')

# %%
TotalcasesState.head()
TotalcasesState = TotalcasesState.sort_values(by = 'Total', ascending=True)
TotalcasesState.head()
TotalcasesState['newTotal'] = TotalcasesState['Total']/100000
TotalcasesState.head()
# Out:
#          States  2015  2016  2017  2018  2019  2020  2021  Total  newTotal
# 34  LAKSHADWEEP     5     3     0     3     0     2     1     14   0.00014
# 32  DAMAN & DIU    38    36    41    35    46     0     0    196   0.00196
# 18     NAGALAND    21    34    33    36    41    48    43    256   0.00256
# 15      MANIPUR    37    37    43    52    58    44    49    320   0.00320
# 17      MIZORAM   123   124    91    79    70   108    99    694   0.00694

# %%
#plt.plot(TotalcasesState['States'], TotalcasesState["Total"], color = 'orange', linewidth = 3)
fig, axs = plt.subplots(figsize = (11,7))
plt.yticks(rotation = "horizontal", fontsize = 7)
axs.barh(TotalcasesState['States'], TotalcasesState['Total'],height=0.8,color=plt.cm.plasma(np.linspace(0, 1, len(TotalcasesState['Total']))))
#plt.ylim(100000,170000)
plt.xlabel('Indian States')
plt.ylabel('Total no. of suicides')
plt.title("Total no. of suicide from 2015-21")
#plt.scatter(TotalYears, Totalsuicides)
plt.show()

# %%
#plt.plot(TotalcasesState['States'], TotalcasesState["Total"], color = 'orange', linewidth = 3)
fig, axs = plt.subplots(figsize = (11,7))
plt.yticks(rotation = "horizontal", fontsize = 7)
axs.barh(TotalcasesState['States'], TotalcasesState['Total'],height=0.8,color=plt.cm.magma(np.linspace(1, 0, len(TotalcasesState['Total']))))
#plt.ylim(100000,170000)
plt.xlabel('Indian States')
plt.ylabel('Total no. of suicides')
plt.title("Total no. of suicide from 2015-21")
#plt.scatter(TotalYears, Totalsuicides)
plt.show()

# %%
#plt.plot(TotalcasesState['States'], TotalcasesState["Total"], color = 'orange', linewidth = 3)
fig, axs = plt.subplots(figsize = (11,7))
plt.yticks(rotation = "horizontal", fontsize = 7)
axs.barh(TotalcasesState['States'], TotalcasesState['Total'],height=0.8,color=plt.cm.viridis(np.linspace(1, 0, len(TotalcasesState['Total']))))
#plt.ylim(100000,170000)
plt.xlabel('Indian States')
plt.ylabel('Total no. of suicides')
plt.title("Total no. of suicide from 2015-21")
#plt.scatter(TotalYears, Totalsuicides)
plt.show()

# %%
#plt.plot(TotalcasesState['States'], TotalcasesState["Total"], color = 'orange', linewidth = 3)
fig, axs = plt.subplots(figsize = (11,7))
plt.yticks(rotation = "horizontal", fontsize = 7)
axs.barh(TotalcasesState['States'], TotalcasesState['Total'],height=0.8,color=plt.cm.inferno(np.linspace(1, 0, len(TotalcasesState['Total']))))
#plt.ylim(100000,170000)
plt.xlabel('Indian States')
plt.ylabel('Total no. of suicides')
plt.title("Total no. of suicide from 2015-21")
#plt.scatter(TotalYears, Totalsuicides)
plt.show()

# %%
fig, axs = plt.subplots(figsize = (11,7))
plt.yticks(rotation = "horizontal", fontsize = 7)
axs.barh(TotalcasesState['States'], TotalcasesState['Total'],height=0.8,color=plt.cm.Pastel1(np.linspace(0, 1, len(TotalcasesState['Total']))))
#plt.ylim(100000,170000)
plt.xlabel('Indian States')
plt.ylabel('Total no. of suicides')
plt.title("Total no. of suicide from 2015-21")
#plt.scatter(TotalYears, Totalsuicides)
plt.show()

# %%
dfon = pd.read_excel('C:/Users/DELL/Desktop/SUCIDE DATA FOR INDIA/Copy of Total 15-21(1).xlsx','Sheet4')

# %%
dfon.head()
dfon = dfon.round(2)
dfon = dfon.iloc[:-1,:]

# %%
dfon.plot.pie(y='percent', labels=dfon['Causes'],colors=plt.cm.viridis(np.linspace(0,1, len(dfon['Causes']))), autopct='%1.1f%%',
        startangle=90, shadow=True, legend=False,figsize = (10,10))

# Add a title
plt.title('Pie Chart Example')
plt.ylabel('')

# Show the chart
plt.show()

# %%
dfon['Causes']
# Out:
# 0                       Bankruptcy
# 1                 Marriage Related
# 2           Failure in Examination
# 3            Impotency/Infertility
# 4                  Family Problems
# 5                          Illness
# 6             Death of Dear Person
# 7                       Drug Abuse
# 8                     Love Affairs
# 9                          Poverty
# 10                    Unemployment
# 11                Property Dispute
# 12     Suspected/ Illicit Relation
# 13                  Physical Abuse
# 14    Professional/Career Problem
# 15                Causes Not Known
# 16                    Other Causes
# Name: Causes, dtype: object

# %%
dt = Marriage_top5.pivot_table(index='Years',columns='States',values='Deaths').
dt
# Out:
# States  MADHYA PRADESH  MAHARASHTRA  ODISHA  UTTAR PRADESH  WEST BENGAL
# Years
# 2015              1011          706     407            648          882
# 2016              1080          676     370            599         1141
# 2017               955          856     272            790         1144
# 2018               979          868     230            921         1354
# 2019               815          905     177            950         1068
# 2020               120         1075       5              2           96
# 2021              1362          773     134           1068          850

# %%
dt = Marriage_top5.pivot_table(index = 'Years', columns = 'States', values = 'Deaths').plot(kind = 'bar', figsize = (8,4))
plt.xlable()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24952\761010590.py in <module>
#       1 dt = Marriage_top5.pivot_table(index = 'Years', columns = 'States', values = 'Deaths').plot(kind = 'bar', figsize = (8,4))
# ----> 2 plt.xlable()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlable'

# %%
display(Marriage_top5.describe().T.style.background_gradient(cmap='Reds', low=0.5, high=1.0))
# Out:
# <style type="text/css">
# #T_d2871_row0_col0, #T_d2871_row1_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_d2871_row0_col1, #T_d2871_row0_col3, #T_d2871_row0_col4, #T_d2871_row0_col5, #T_d2871_row0_col6, #T_d2871_row0_col7, #T_d2871_row1_col2 {
#   background-color: #fdcab5;
#   color: #000000;
# }
# #T_d2871_row0_col2, #T_d2871_row1_col1, #T_d2871_row1_col3, #T_d2871_row1_col4, #T_d2871_row1_col5, #T_d2871_row1_col6, #T_d2871_row1_col7 {
#   background-color: #f14432;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d2871">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d2871_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_d2871_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_d2871_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_d2871_level0_col3" class="col_heading level0 col3" >min</th>
# ...
